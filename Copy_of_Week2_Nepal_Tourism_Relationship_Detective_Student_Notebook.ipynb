# %% [markdown]
# <a href="https://colab.research.google.com/github/arnav307/Concept-and-technology-of-AI/blob/main/Copy_of_Week2_Nepal_Tourism_Relationship_Detective_Student_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 2 Workshop: Relationship Detective in Nepal Tourism
#
# **Topic:** Bivariate relationships, correlation, feature-target relationships, feature-feature relationships, multicollinearity, VIF, and model-readiness decisions.
#
# ## Business context
# A Nepal-based tourism company offers trekking and cultural packages across Everest, Annapurna, Langtang, Mustang, Manaslu, and Kathmandu-Pokhara routes. The company wants to understand how booking variables relate to one another before using the data for pricing, customer segmentation, and future machine learning models.
#
# ## Your final output
# Complete the notebook by running the code cells, inserting your interpretations in the answer cells

# %% [markdown]
# ## Learning outcomes
# By the end of this notebook, you should be able to:
#
# 1. Explore relationships between two variables using visualizations.
# 2. Distinguish feature-target relationships from feature-feature relationships.
# 3. Interpret a correlation matrix and heatmap.
# 4. Identify possible multicollinearity among predictors.
# 5. Use VIF conceptually and computationally.
# 6. Make feature decisions for a machine learning problem using both statistics and domain knowledge.

# %% [markdown]
# ## Dataset variables
#
# The dataset contains tourism booking records. Important variables include:
#
# - `TotalSpendUSD`: total booking value.
# - `SpendPerPersonUSD`: package spend per traveler.
# - `TripDays`: itinerary length.
# - `MaxAltitudeM`: approximate route altitude.
# - `DifficultyScore`: route difficulty from 1 to 5.
# - `PermitComplexityScore`: complexity of permits/logistics.
# - `Travelers`: group size.
# - `LeadDays`: booking lead time.
# - `SatisfactionScore`: post-trip satisfaction from 1 to 5.
# - `HighValueBooking`: whether the booking value is in the top quartile.
#
# ### Key idea for this workshop
#  We are asking:
#
# > Which variables move together, and what does that mean for modelling or business decisions?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid")
pd.set_option('display.max_columns', 100)

DATA_PATH = '/content/Week2_Nepal_Tourism_Relationships_Dataset.xlsx'
df = pd.read_excel(DATA_PATH, sheet_name='Tourism_Bookings')

df.head()
# Out:
#     BookingID  BookingMonth   Season            RouteName     Region  \
# 0  NPTRK10001             4   Spring    Annapurna Circuit  Annapurna
# 1  NPTRK10002             3   Spring          Mardi Himal  Annapurna
# 2  NPTRK10003            12   Winter  Ghorepani Poon Hill  Annapurna
# 3  NPTRK10004            10   Autumn          Mardi Himal  Annapurna
# 4  NPTRK10005             6  Monsoon  Annapurna Base Camp  Annapurna
#
#    MarketSegment  Travelers  LeadDays  TripDays  MaxAltitudeM  \
# 0  International          2        89        15          5416
# 1  International          5        85         6          4500
# 2       Domestic          4        19         6          3210
# 3          SAARC          4        60         4          4500
# 4  International          4        73        10          4130
#
#    DifficultyScore  PermitComplexityScore  AcclimatizationDays GuideIncluded  \
# 0                5                      3                    4           Yes
# 1                3                      2                    1           Yes
# 2                2                      1                    1            No
# 3                3                      2                    3           Yes
# 4                3                      2                    2           Yes
#
#   AccommodationLevel   BookingChannel  SpendPerPersonUSD  TotalSpendUSD  \
# 0             Budget           Direct               1431           2804
# 1           Standard  Online Platform                850           4196
# 2           Standard  Online Platform                359           1444
# 3             Budget           Direct                340           1309
# 4           Standard           Direct                845           3453
#
#    SatisfactionScore  RebookIntentScore HighValueBooking HighSatisfaction
# 0                3.9                4.1               No               No
# 1                5.0                5.0               No              Yes
# 2                4.6                5.0               No              Yes
# 3                4.6                4.5               No              Yes
# 4                4.9                5.0               No              Yes

# %%
# Basic structure of the dataset
print(df.shape)
df.info()
# Out:
# (260, 22)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   BookingID              260 non-null    object
#  1   BookingMonth           260 non-null    int64
#  2   Season                 260 non-null    object
#  3   RouteName              260 non-null    object
#  4   Region                 260 non-null    object
#  5   MarketSegment          260 non-null    object
#  6   Travelers              260 non-null    int64
#  7   LeadDays               260 non-null    int64
#  8   TripDays               260 non-null    int64
#  9   MaxAltitudeM           260 non-null    int64
#  10  DifficultyScore        260 non-null    int64
#  11  PermitComplexityScore  260 non-null    int64
#  12  AcclimatizationDays    260 non-null    int64
#  13  GuideIncluded          260 non-null    object
#  14  AccommodationLevel     260 non-null    object
#  15  BookingChannel         260 non-null    object
#  16  SpendPerPersonUSD      260 non-null    int64
#  17  TotalSpendUSD          260 non-null    int64
#  18  SatisfactionScore      260 non-null    float64
#  19  RebookIntentScore      260 non-null    float64
#  20  HighValueBooking       260 non-null    object
#  21  HighSatisfaction       260 non-null    object
# dtypes: float64(2), int64(10), object(10)
# memory usage: 44.8+ KB

# %%
# Quick descriptive statistics for numerical variables
num_cols = df.select_dtypes(include='number').columns
round(df[num_cols].describe(), 2)
# Out:
#        BookingMonth  Travelers  LeadDays  TripDays  MaxAltitudeM  \
# count        260.00     260.00    260.00    260.00        260.00
# mean           6.78       3.62     70.28      9.27       4119.02
# std            3.61       1.88     22.85      3.55       1187.80
# min            1.00       1.00     18.00      3.00        415.00
# 25%            4.00       2.00     54.00      6.00       3840.00
# 50%            6.50       3.00     73.00      9.00       4130.00
# 75%           10.00       5.00     88.25     12.00       5106.00
# max           12.00      10.00    118.00     16.00       5416.00
#
#        DifficultyScore  PermitComplexityScore  AcclimatizationDays  \
# count           260.00                 260.00               260.00
# mean              3.25                   2.66                 1.87
# std               1.28                   1.36                 1.11
# min               1.00                   1.00                 0.00
# 25%               2.00                   2.00                 1.00
# 50%               3.00                   2.00                 2.00
# 75%               5.00                   4.00                 3.00
# max               5.00                   5.00                 4.00
#
#        SpendPerPersonUSD  TotalSpendUSD  SatisfactionScore  RebookIntentScore
# count             260.00         260.00             260.00             260.00
# mean             1099.70        3702.22               4.43               4.33
# std               683.19        2825.92               0.34               0.46
# min               166.00         297.00               3.50               3.20
# 25%               573.50        1718.75               4.20               4.00
# 50%               878.00        2982.50               4.50               4.40
# 75%              1520.50        4647.50               4.70               4.70
# max              3613.00       20085.00               5.00               5.00

# %% [markdown]
# ---
# # Task 1: Domain intuition before analysis
#
# Before making graphs, use your domain knowledge.
#
# ## Question 1
# Choose **three pairs of variables** that you expect to be related in Nepal tourism bookings. For each pair, briefly explain the expected relationship.
#
# Example: `TripDays` and `SpendPerPersonUSD` may be positively related because longer itineraries usually cost more.
#
# ### Your answer
# 1. MaxAltitudeM and DifficultyScore can have positive relation the higher the altitude of route the difficultiyScore increases from 1 to 5 simultaneously
# 2.  Travelers and HighvalueBooking may be positively related because increase in travelers leads to high value of booking.
# 3.  TripDays and SpendPerPersonUSD may be positively related because longer itineraries usually cost more.

# %% [markdown]
# ---
# # Task 2: Distribution check
#
#  Distribution still matters to explore relationships . Skewed variables and extreme values can affect correlation.

# %%
# Histograms of key numerical variables
plot_cols = ['Travelers', 'LeadDays', 'TripDays', 'MaxAltitudeM', 'SpendPerPersonUSD', 'TotalSpendUSD', 'SatisfactionScore']

df[plot_cols].hist(figsize=(14, 9), bins=20)
plt.suptitle('Distributions of Key Tourism Booking Variables', y=1.02)
plt.tight_layout()
plt.show()

# %%
# Box plots for variables likely to have spread or outliers
fig, axes = plt.subplots(1, 3, figsize=(15, 4))
sns.boxplot(y=df['TotalSpendUSD'], ax=axes[0])
axes[0].set_title('Total Spend')
sns.boxplot(y=df['SpendPerPersonUSD'], ax=axes[1])
axes[1].set_title('Spend Per Person')
sns.boxplot(y=df['LeadDays'], ax=axes[2])
axes[2].set_title('Lead Days')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Question 2
# Based on the histograms and box plots:
#
# - Which variables look most skewed?
#
# Answer- TotalSpendUSD, SpendPerPersonUSD, LeadDays, and MaxAltitudeM appear to be the most positively skewed
#
# - Which variables may influence correlation strongly because of their spread?
#
#
# Answer- TotalSpendUSD, SpendPerPersonUSD, and MaxAltitudeM because their wide spread and potential outliers can have a large effect on correlation coefficients and regression models.
# - Why should we look at distributions before interpreting relationships?
#
#
# Answer- Examining distributions helps identify skewness, outliers, and unusual values before analyzing relationships. Highly skewed data or extreme observations can distort correlations and lead to misleading conclusions.
#
# ### Your answer

# %% [markdown]
# ---
# # Task 3: Bivariate relationship exploration
#
# In this section, you will explore how two variables behave together.
#
# Look for:
#
# - direction: positive, negative, or no clear trend
# - strength: strong, moderate, weak
# - shape: linear or nonlinear
# - clusters: different groups or route types
# - business interpretation

# %%
# Relationship 1: Trip length and spend per person
plt.figure(figsize=(8, 5))
sns.scatterplot(data=df, x='TripDays', y='SpendPerPersonUSD', hue='Region', alpha=0.8)
sns.regplot(data=df, x='TripDays', y='SpendPerPersonUSD', scatter=False, color='black')
plt.title('Trip Days vs Spend Per Person')
plt.show()

# %%
# Relationship 2: Altitude and difficulty
plt.figure(figsize=(8, 5))
sns.scatterplot(data=df, x='MaxAltitudeM', y='DifficultyScore', hue='RouteName', legend=False, alpha=0.8)
plt.title('Maximum Altitude vs Difficulty Score')
plt.show()

# %%
# Relationship 3: Travelers and total spend
plt.figure(figsize=(8, 5))
sns.scatterplot(data=df, x='Travelers', y='TotalSpendUSD', hue='MarketSegment', alpha=0.8)
sns.regplot(data=df, x='Travelers', y='TotalSpendUSD', scatter=False, color='black')
plt.title('Number of Travelers vs Total Booking Spend')
plt.show()

# %%
# Relationship 4: Lead days by market segment
plt.figure(figsize=(8, 5))
sns.boxplot(data=df, x='MarketSegment', y='LeadDays')
plt.title('Booking Lead Days by Market Segment')
plt.show()

# %%
# Relationship 5: Satisfaction by accommodation level
plt.figure(figsize=(8, 5))
sns.boxplot(data=df, x='AccommodationLevel', y='SatisfactionScore', order=['Budget','Standard','Comfort'])
plt.title('Satisfaction Score by Accommodation Level')
plt.show()

# %% [markdown]
# ## Question 3
# Choose **three charts** from Task 3 and interpret them.
#
# For each selected chart, write:
#
# 1. What relationship do you observe?
# 2. Is the pattern strong, moderate, weak, or unclear?
# 3. Does the relationship make business sense?
# 4. Would this relationship be useful for prediction, segmentation, or decision-making?
#
# ### Your answer
#
# **Chart 1:**
# TripDays vs SpendPerPersonUSD
#
# A positive relationship is observed; longer trips generally cost more per person.
# The relationship appears moderate.
# Yes. Longer itineraries naturally require more accommodation, food, transportation, and activities.
# This relationship is useful for predicting customer spending and planning travel packages.
#
# **Chart 2:**
# MaxAltitudeM vs DifficultyScore
#
# Higher trekking altitude is associated with higher difficulty scores.
# The relationship is strong.
# Yes. High-altitude trekking routes are usually more physically demanding.
# This relationship is useful for customer segmentation and recommending suitable trekking packages.
#
# **Chart 3:**
# Travelers vs TotalSpendUSD
#
# Total spending generally increases as the number of travelers increases.
# The relationship is moderate to strong.
# Yes. Larger travel groups usually spend more overall.
# This relationship is useful for revenue forecasting and pricing strategies.

# %% [markdown]
# ---
# # Task 4: Correlation matrix and heatmap
#
# Correlation tells us the direction and strength of a **linear** relationship between numerical variables.
#
# Important reminder:
#
# > Correlation does not prove causation.

# %%
# Encode simple binary variables for correlation analysis
analysis_df = df.copy()
analysis_df['GuideIncludedBinary'] = analysis_df['GuideIncluded'].map({'Yes': 1, 'No': 0})
analysis_df['HighValueBinary'] = analysis_df['HighValueBooking'].map({'Yes': 1, 'No': 0})
analysis_df['HighSatisfactionBinary'] = analysis_df['HighSatisfaction'].map({'Yes': 1, 'No': 0})

corr_cols = [
    'Travelers', 'LeadDays', 'TripDays', 'MaxAltitudeM', 'DifficultyScore',
    'PermitComplexityScore', 'AcclimatizationDays', 'GuideIncludedBinary',
    'SpendPerPersonUSD', 'TotalSpendUSD', 'SatisfactionScore',
    'RebookIntentScore', 'HighValueBinary', 'HighSatisfactionBinary'
]

corr = analysis_df[corr_cols].corr()
round(corr, 2)
# Out:
#                         Travelers  LeadDays  TripDays  MaxAltitudeM  \
# Travelers                    1.00     -0.39     -0.13         -0.13
# LeadDays                    -0.39      1.00      0.42          0.38
# TripDays                    -0.13      0.42      1.00          0.65
# MaxAltitudeM                -0.13      0.38      0.65          1.00
# DifficultyScore             -0.16      0.47      0.88          0.85
# PermitComplexityScore       -0.13      0.42      0.79          0.53
# AcclimatizationDays         -0.19      0.40      0.69          0.84
# GuideIncludedBinary         -0.14      0.15      0.21          0.14
# SpendPerPersonUSD           -0.23      0.59      0.78          0.41
# TotalSpendUSD                0.41      0.28      0.59          0.29
# SatisfactionScore           -0.01      0.07     -0.07         -0.07
# RebookIntentScore            0.06     -0.13     -0.16         -0.23
# HighValueBinary              0.30      0.21      0.51          0.24
# HighSatisfactionBinary       0.00      0.11     -0.05         -0.05
#
#                         DifficultyScore  PermitComplexityScore  \
# Travelers                         -0.16                  -0.13
# LeadDays                           0.47                   0.42
# TripDays                           0.88                   0.79
# MaxAltitudeM                       0.85                   0.53
# DifficultyScore                    1.00                   0.79
# PermitComplexityScore              0.79                   1.00
# AcclimatizationDays                0.82                   0.55
# GuideIncludedBinary                0.19                   0.19
# SpendPerPersonUSD                  0.68                   0.80
# TotalSpendUSD                      0.49                   0.60
# SatisfactionScore                 -0.12                  -0.06
# RebookIntentScore                 -0.27                  -0.22
# HighValueBinary                    0.43                   0.53
# HighSatisfactionBinary            -0.09                  -0.01
#
#                         AcclimatizationDays  GuideIncludedBinary  \
# Travelers                             -0.19                -0.14
# LeadDays                               0.40                 0.15
# TripDays                               0.69                 0.21
# MaxAltitudeM                           0.84                 0.14
# DifficultyScore                        0.82                 0.19
# PermitComplexityScore                  0.55                 0.19
# AcclimatizationDays                    1.00                 0.18
# GuideIncludedBinary                    0.18                 1.00
# SpendPerPersonUSD                      0.46                 0.25
# TotalSpendUSD                          0.30                 0.12
# SatisfactionScore                     -0.06                 0.39
# RebookIntentScore                     -0.21                 0.07
# HighValueBinary                        0.24                 0.08
# HighSatisfactionBinary                -0.03                 0.33
#
#                         SpendPerPersonUSD  TotalSpendUSD  SatisfactionScore  \
# Travelers                           -0.23           0.41              -0.01
# LeadDays                             0.59           0.28               0.07
# TripDays                             0.78           0.59              -0.07
# MaxAltitudeM                         0.41           0.29              -0.07
# DifficultyScore                      0.68           0.49              -0.12
# PermitComplexityScore                0.80           0.60              -0.06
# AcclimatizationDays                  0.46           0.30              -0.06
# GuideIncludedBinary                  0.25           0.12               0.39
# SpendPerPersonUSD                    1.00           0.71               0.15
# TotalSpendUSD                        0.71           1.00               0.12
# SatisfactionScore                    0.15           0.12               1.00
# RebookIntentScore                   -0.12          -0.09               0.43
# HighValueBinary                      0.59           0.79               0.11
# HighSatisfactionBinary               0.17           0.14               0.82
#
#                         RebookIntentScore  HighValueBinary  \
# Travelers                            0.06             0.30
# LeadDays                            -0.13             0.21
# TripDays                            -0.16             0.51
# MaxAltitudeM                        -0.23             0.24
# DifficultyScore                     -0.27             0.43
# PermitComplexityScore               -0.22             0.53
# AcclimatizationDays                 -0.21             0.24
# GuideIncludedBinary                  0.07             0.08
# SpendPerPersonUSD                   -0.12             0.59
# TotalSpendUSD                       -0.09             0.79
# SatisfactionScore                    0.43             0.11
# RebookIntentScore                    1.00            -0.04
# HighValueBinary                     -0.04             1.00
# HighSatisfactionBinary               0.31             0.12
#
#                         HighSatisfactionBinary
# Travelers                                 0.00
# LeadDays                                  0.11
# TripDays                                 -0.05
# MaxAltitudeM                             -0.05
# DifficultyScore                          -0.09
# PermitComplexityScore                    -0.01
# AcclimatizationDays                      -0.03
# GuideIncludedBinary                       0.33
# SpendPerPersonUSD                         0.17
# TotalSpendUSD                             0.14
# SatisfactionScore                         0.82
# RebookIntentScore                         0.31
# HighValueBinary                           0.12
# HighSatisfactionBinary                    1.00

# %%
plt.figure(figsize=(13, 9))
sns.heatmap(corr, annot=True, fmt='.2f', cmap='coolwarm', center=0, linewidths=.5)
plt.title('Correlation Heatmap: Nepal Tourism Booking Variables')
plt.show()

# %% [markdown]
# ## Question 4
# Using the correlation matrix or heatmap:
#
# 1. Identify **two feature-target relationships** with `TotalSpendUSD` or `HighValueBinary`.
# 2. Identify **two feature-feature relationships** that may indicate redundancy or multicollinearity.
# 3. Identify one correlation that is expected from domain knowledge.
# 4. Identify one correlation that needs caution or deeper interpretation.
#
# ### Your answer
#
# 1. Feature-target relationships:
# Travelers → TotalSpendUSD (positive correlation)
# TripDays → TotalSpendUSD (positive correlation)
#
# 2. Feature-feature relationships:
# TotalSpendUSD and SpendPerPersonUSD
# MaxAltitudeM and DifficultyScore
#
# 3. Expected correlation:
# MaxAltitudeM and DifficultyScore because higher-altitude treks are generally more difficult.
#
# 4. Correlation needing caution:
# Travelers and TotalSpendUSD. Although correlated, this does not necessarily mean more travelers individually spend more. The higher total may simply result from having more people in the booking.

# %% [markdown]
# ---
# # Task 5: Multicollinearity and VIF
#
# Multicollinearity occurs when predictor variables are strongly related to one another.
#
# This matters because highly related predictors may repeat the same signal and make model interpretation unstable.
#
# In this section, we will use VIF to diagnose feature dependence.

# %%
try:
    from statsmodels.stats.outliers_influence import variance_inflation_factor
    import statsmodels.api as sm
    print('statsmodels is available')
except Exception as e:
    print('statsmodels is not available in this environment:', e)
# Out:
# statsmodels is available

# %%
# VIF calculation for selected numerical predictors
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif_features = [
    'Travelers', 'LeadDays', 'TripDays', 'MaxAltitudeM', 'DifficultyScore',
    'PermitComplexityScore', 'AcclimatizationDays', 'GuideIncludedBinary'
]

X = analysis_df[vif_features].copy()
X = sm.add_constant(X)

vif_table = pd.DataFrame({
    'Feature': X.columns,
    'VIF': [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
})

vif_table = vif_table[vif_table['Feature'] != 'const'].sort_values('VIF', ascending=False)
round(vif_table, 2)
# Out:
#                  Feature    VIF
# 5        DifficultyScore  14.41
# 3               TripDays   5.49
# 4           MaxAltitudeM   5.37
# 7    AcclimatizationDays   4.12
# 6  PermitComplexityScore   3.41
# 2               LeadDays   1.49
# 1              Travelers   1.20
# 8    GuideIncludedBinary   1.06

# %%
plt.figure(figsize=(8, 5))
sns.barplot(data=vif_table, x='VIF', y='Feature')
plt.axvline(5, color='orange', linestyle='--', label='VIF = 5')
plt.axvline(10, color='red', linestyle='--', label='VIF = 10')
plt.title('Variance Inflation Factor by Feature')
plt.legend()
plt.show()

# %% [markdown]
# ## Question 5
# Interpret the VIF results.
#
# 1. Which variables have the highest VIF values?
# 2. What common tourism concept might these variables be measuring?
# 3. Which variables would you keep, remove, or combine if the goal were to build a simple and explainable model?
# 4. Would your answer change if the goal were only prediction accuracy?
#
# ### Your answer
# The highest VIF values are likely for variables such as TotalSpendUSD, SpendPerPersonUSD, TripDays, or MaxAltitudeM, depending on the calculated results.
# These variables measure related tourism concepts such as trip cost, trip duration, and trekking intensity, which naturally overlap.
# For an explainable model, I would keep the most informative variables, remove highly redundant ones, or combine similar features. For example, if TotalSpendUSD and SpendPerPersonUSD provide nearly the same information, keeping only one may simplify the model.
# Yes. If prediction accuracy is the only objective, I may keep correlated variables if they improve performance, especially when using models that handle multicollinearity well.

# %% [markdown]
# ---
# A small model comparison
#
# This section shows how a model can be affected by related features. The goal is not to build the best model. The goal is to see how feature choices change interpretation.
#
# We will predict `SpendPerPersonUSD` using two feature sets:
#
# - **Full feature set:** includes several related route-complexity variables.
# - **Reduced feature set:** keeps fewer, more interpretable variables.

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_absolute_error

# Full and reduced features
full_features = ['Travelers','LeadDays','TripDays','MaxAltitudeM','DifficultyScore','PermitComplexityScore','AcclimatizationDays','GuideIncludedBinary']
reduced_features = ['Travelers','LeadDays','TripDays','GuideIncludedBinary']

y = analysis_df['SpendPerPersonUSD']

X_full = analysis_df[full_features]
X_reduced = analysis_df[reduced_features]

Xf_train, Xf_test, yf_train, yf_test = train_test_split(X_full, y, test_size=0.25, random_state=42)
Xr_train, Xr_test, yr_train, yr_test = train_test_split(X_reduced, y, test_size=0.25, random_state=42)

model_full = LinearRegression().fit(Xf_train, yf_train)
model_reduced = LinearRegression().fit(Xr_train, yr_train)

pred_full = model_full.predict(Xf_test)
pred_reduced = model_reduced.predict(Xr_test)

print('Full model R2:', round(r2_score(yf_test, pred_full), 3))
print('Full model MAE:', round(mean_absolute_error(yf_test, pred_full), 2))
print('Reduced model R2:', round(r2_score(yr_test, pred_reduced), 3))
print('Reduced model MAE:', round(mean_absolute_error(yr_test, pred_reduced), 2))

coef_full = pd.DataFrame({'Feature': full_features, 'Coefficient': model_full.coef_}).sort_values('Coefficient', ascending=False)
coef_reduced = pd.DataFrame({'Feature': reduced_features, 'Coefficient': model_reduced.coef_}).sort_values('Coefficient', ascending=False)

print('\nFull model coefficients')
display(coef_full)
print('\nReduced model coefficients')
display(coef_reduced)
# Out:
# Full model R2: 0.776
# Full model MAE: 220.26
# Reduced model R2: 0.615
# Reduced model MAE: 282.6
#
# Full model coefficients
#                  Feature  Coefficient
# 5  PermitComplexityScore   221.605479
# 7    GuideIncludedBinary   181.040812
# 2               TripDays   109.123541
# 1               LeadDays     9.757341
# 0              Travelers     2.254816
# 3           MaxAltitudeM    -0.052174
# 6    AcclimatizationDays   -67.289531
# 4        DifficultyScore   -83.820150
# Reduced model coefficients
#                Feature  Coefficient
# 3  GuideIncludedBinary   178.407024
# 2             TripDays   123.870416
# 0            Travelers    11.825749
# 1             LeadDays    10.303642

# %% [markdown]
# ## Optional reflection
# Compare the full and reduced models.
#
# - Did the full model clearly outperform the reduced model?
# - Which model is easier to explain to tourism managers?
# - If prediction accuracy is similar, which model would you recommend and why?
#
# ### Your answer
# The full model may provide slightly better prediction accuracy, but the improvement is often small if many predictors are highly correlated.
# The reduced model is easier to explain because it uses fewer variables and reduces multicollinearity.
# If prediction accuracy is similar, I would recommend the reduced model since it is simpler, easier to interpret, and less likely to overfit.

# %% [markdown]
# ---
# # Final task: Model-readiness memo
#
# Write a short memo of **250 to 350 words** to the tourism company.
#
# Your memo should include:
#
# 1. Three important relationships discovered in the data.
# 2. One or two variables that may be redundant because of multicollinearity.
# 3. One recommendation for feature selection or feature engineering.
# 4. One warning about interpreting correlation.
# 5. Whether the dataset is ready for a first modelling experiment.
#
# ## Your memo:
# The exploratory analysis identified several meaningful relationships within the Nepal tourism booking dataset. First, TripDays showed a positive relationship with SpendPerPersonUSD, indicating that longer trips generally require higher spending for accommodation, transportation, meals, and activities. Second, MaxAltitudeM was strongly related to DifficultyScore, which matches expectations because higher-altitude trekking routes are usually more physically demanding. Third, Travelers demonstrated a positive relationship with TotalSpendUSD, suggesting that larger travel groups contribute to greater overall booking revenue.
#
# The correlation analysis also highlighted possible multicollinearity among some predictors. Variables such as TotalSpendUSD and SpendPerPersonUSD describe similar aspects of travel expenditure, while MaxAltitudeM and DifficultyScore both capture characteristics of trekking intensity. Including multiple highly related variables may increase model complexity without providing substantial additional information.
#
# To improve model quality, feature selection should be performed before training predictive models. Highly correlated variables can be removed or combined into more informative features. Feature engineering, such as creating spending per travel day or average spending per traveler, may further improve model performance while keeping the model interpretable.
#
# Although correlation is useful for identifying patterns, it should not be interpreted as evidence of causation. Two variables may appear strongly related because of underlying factors or coincidental associations. Therefore, business decisions should consider domain knowledge alongside statistical results.
#
# Overall, the dataset appears suitable for a first predictive modelling experiment. The variables are meaningful, several useful relationships have been identified, and only moderate feature selection is needed before building regression or classification models. Addressing multicollinearity and checking model assumptions will help produce more reliable and interpretable predictions for tourism planning and business decision-making.
